# %% [markdown]
# <a href="https://colab.research.google.com/github/rskarbez/colab_notebooks/blob/main/Week2_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Notebook from week 2, session 2
#
# Hi, this is my name

# %%
name = 'Rick Skarbez'
print(name)
# Out:
# Rick Skarbez

# %%
print(type(name))
name
# Out:
# <class 'str'>
# 'Rick Skarbez'

# %%
fav_number = 12
golden_ratio = 1.618
print(type(fav_number))
print(type(golden_ratio))
# Out:
# <class 'int'>
# <class 'float'>

# %%
import keyword
print(keyword.kwlist)
for word in keyword.kwlist:
  print(word)
len(keyword.kwlist)
# Out:
# ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# False
# None
# True
# and
# as
# assert
# async
# await
# break
# class
# continue
# def
# del
# elif
# else
# except
# finally
# for
# from
# global
# if
# import
# in
# is
# lambda
# nonlocal
# not
# or
# pass
# raise
# return
# try
# while
# with
# yield
# 35

# %%
False = 42
# Out:
#   File "<ipython-input-13-ea98e3dac4de>", line 1
#     False = 42
#               ^
# SyntaxError: can't assign to keyword

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
len(name)
# Out:
# 12

# %%
for char in name:
  print(char)
# Out:
# R
# i
# c
# k
#
# S
# k
# a
# r
# b
# e
# z

# %%
while True:
  print('This is an infinite loop.')
# Out:
# Streaming output truncated to the last 5000 lines.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# This is an infinite loop.
# ...

# %%
i = 0
while i < 10:
  print(i*i)
  i += 1
# Out:
# 0
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
